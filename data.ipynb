# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("BLI.csv")

# %%
df
# Out:
#      LOCATION     Country INDICATOR                          Indicator  \
# 0         AUS   Australia   JE_LMIS           Labour market insecurity
# 1         AUT     Austria   JE_LMIS           Labour market insecurity
# 2         BEL     Belgium   JE_LMIS           Labour market insecurity
# 3         CAN      Canada   JE_LMIS           Labour market insecurity
# 4         CZE     Czechia   JE_LMIS           Labour market insecurity
# ...       ...         ...       ...                                ...
# 2364      CRI  Costa Rica   PS_REPH                      Homicide rate
# 2365      CRI  Costa Rica   PS_REPH                      Homicide rate
# 2366      CRI  Costa Rica   WL_EWLH  Employees working very long hours
# 2367      CRI  Costa Rica   WL_EWLH  Employees working very long hours
# 2368      CRI  Costa Rica   WL_EWLH  Employees working very long hours
#
#      MEASURE Measure INEQUALITY Inequality Unit Code        Unit  \
# ...

# %%
satisfaction_df = df[df['INDICATOR'] == 'SW_LIFS']

# %%
satisfaction_df
# Out:
#      LOCATION     Country INDICATOR          Indicator MEASURE Measure  \
# 1722      AUS   Australia   SW_LIFS  Life satisfaction       L   Value
# 1723      AUT     Austria   SW_LIFS  Life satisfaction       L   Value
# 1724      BEL     Belgium   SW_LIFS  Life satisfaction       L   Value
# 1725      CAN      Canada   SW_LIFS  Life satisfaction       L   Value
# 1726      CZE     Czechia   SW_LIFS  Life satisfaction       L   Value
# ...       ...         ...       ...                ...     ...     ...
# 2358      CRI  Costa Rica   SW_LIFS  Life satisfaction       L   Value
# 2359      CRI  Costa Rica   SW_LIFS  Life satisfaction       L   Value
# 2360      CRI  Costa Rica   SW_LIFS  Life satisfaction       L   Value
# 2361      CRI  Costa Rica   SW_LIFS  Life satisfaction       L   Value
# 2362      CRI  Costa Rica   SW_LIFS  Life satisfaction       L   Value
#
#      INEQUALITY Inequality Unit Code           Unit  PowerCode Code PowerCode  \
# ...

# %%
satisfaction_df = satisfaction_df[satisfaction_df['INEQUALITY'] == 'TOT']

# %%
satisfaction_df
# Out:
#      LOCATION          Country INDICATOR          Indicator MEASURE Measure  \
# 1722      AUS        Australia   SW_LIFS  Life satisfaction       L   Value
# 1723      AUT          Austria   SW_LIFS  Life satisfaction       L   Value
# 1724      BEL          Belgium   SW_LIFS  Life satisfaction       L   Value
# 1725      CAN           Canada   SW_LIFS  Life satisfaction       L   Value
# 1726      CZE          Czechia   SW_LIFS  Life satisfaction       L   Value
# 1727      DNK          Denmark   SW_LIFS  Life satisfaction       L   Value
# 1728      FIN          Finland   SW_LIFS  Life satisfaction       L   Value
# 1729      FRA           France   SW_LIFS  Life satisfaction       L   Value
# 1730      DEU          Germany   SW_LIFS  Life satisfaction       L   Value
# 1731      GRC           Greece   SW_LIFS  Life satisfaction       L   Value
# 1732      HUN          Hungary   SW_LIFS  Life satisfaction       L   Value
# ...

# %%
satisfaction_df.to_csv('Filtered_BLI.csv', index=False)

# %%
df = pd.read_csv("PIB.csv")

# %%
df
# Out:
#     LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME         Value  \
# 0        AUS       GDP     TOT  USD_CAP         A  2018  53118.792237
# 1        AUS       GDP     TOT  USD_CAP         A  2019  52921.968891
# 2        AUS       GDP     TOT  USD_CAP         A  2020  56000.130076
# 3        AUS       GDP     TOT  USD_CAP         A  2021  62745.388207
# 4        AUS       GDP     TOT  USD_CAP         A  2022  69418.944207
# ..       ...       ...     ...      ...       ...   ...           ...
# 299      CMR       GDP     TOT  USD_CAP         A  2019   3900.880855
# 300      CMR       GDP     TOT  USD_CAP         A  2020   3861.209890
# 301      SEN       GDP     TOT  USD_CAP         A  2018   3416.171427
# 302      SEN       GDP     TOT  USD_CAP         A  2019   3530.096494
# 303      SEN       GDP     TOT  USD_CAP         A  2020   3513.149951
#
#     Flag Codes
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# ...

# %%
df = df[df['TIME'] == 2020]

# %%
df
# Out:
#     LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME         Value  \
# 2        AUS       GDP     TOT  USD_CAP         A  2020  56000.130076
# 7        AUT       GDP     TOT  USD_CAP         A  2020  57235.673886
# 12       BEL       GDP     TOT  USD_CAP         A  2020  54652.164337
# 17       CAN       GDP     TOT  USD_CAP         A  2020  47226.357276
# 22       CZE       GDP     TOT  USD_CAP         A  2020  42817.867499
# ..       ...       ...     ...      ...       ...   ...           ...
# 289      ALB       GDP     TOT  USD_CAP         A  2020  14033.967211
# 292      SRB       GDP     TOT  USD_CAP         A  2020  19547.725670
# 296      GEO       GDP     TOT  USD_CAP         A  2020  14731.202573
# 300      CMR       GDP     TOT  USD_CAP         A  2020   3861.209890
# 303      SEN       GDP     TOT  USD_CAP         A  2020   3513.149951
#
#     Flag Codes
# 2          NaN
# 7          NaN
# 12         NaN
# 17         NaN
# 22         NaN
# ..         ...
# ...

# %%
df.to_csv('Filtered_GPD.csv', index=False)

# %%
df = df[['LOCATION', 'Value']]

# %%
df
# Out:
#     LOCATION         Value
# 2        AUS  56000.130076
# 7        AUT  57235.673886
# 12       BEL  54652.164337
# 17       CAN  47226.357276
# 22       CZE  42817.867499
# ..       ...           ...
# 289      ALB  14033.967211
# 292      SRB  19547.725670
# 296      GEO  14731.202573
# 300      CMR   3861.209890
# 303      SEN   3513.149951
#
# [66 rows x 2 columns]

# %%
df.to_csv('Filtered_GPD.csv', index=False)

# %%
df = df.rename(columns={'Value': 'GPD'})

# %%
df = pd.read_csv('Filtered_BLI.csv')

# %%
df
# Out:
#    LOCATION          Country INDICATOR          Indicator MEASURE Measure  \
# 0       AUS        Australia   SW_LIFS  Life satisfaction       L   Value
# 1       AUT          Austria   SW_LIFS  Life satisfaction       L   Value
# 2       BEL          Belgium   SW_LIFS  Life satisfaction       L   Value
# 3       CAN           Canada   SW_LIFS  Life satisfaction       L   Value
# 4       CZE          Czechia   SW_LIFS  Life satisfaction       L   Value
# 5       DNK          Denmark   SW_LIFS  Life satisfaction       L   Value
# 6       FIN          Finland   SW_LIFS  Life satisfaction       L   Value
# 7       FRA           France   SW_LIFS  Life satisfaction       L   Value
# 8       DEU          Germany   SW_LIFS  Life satisfaction       L   Value
# 9       GRC           Greece   SW_LIFS  Life satisfaction       L   Value
# 10      HUN          Hungary   SW_LIFS  Life satisfaction       L   Value
# 11      ISL          Iceland   SW_LIFS  Life satisfaction       L   Value
# ...

# %%
df = df[['LOCATION', 'Value']]

# %%
df
# Out:
#    LOCATION  Value
# 0       AUS    7.1
# 1       AUT    7.2
# 2       BEL    6.8
# 3       CAN    7.0
# 4       CZE    6.9
# 5       DNK    7.5
# 6       FIN    7.9
# 7       FRA    6.7
# 8       DEU    7.3
# 9       GRC    5.8
# 10      HUN    6.0
# 11      ISL    7.6
# 12      IRL    7.0
# 13      ITA    6.5
# 14      JPN    6.1
# 15      KOR    5.8
# 16      LUX    7.4
# 17      MEX    6.0
# 18      NLD    7.5
# 19      NZL    7.3
# 20      NOR    7.3
# 21      POL    6.1
# 22      PRT    5.8
# 23      SVK    6.5
# 24      ESP    6.5
# 25      SWE    7.3
# 26      CHE    7.5
# 27      TUR    4.9
# 28      GBR    6.8
# 29      USA    7.0
# 30      BRA    6.1
# 31      CHL    6.2
# 32      EST    6.5
# 33      ISR    7.2
# 34      LVA    6.2
# 35      RUS    5.5
# 36      SVN    6.5
# 37      ZAF    4.9
# 38     OECD    6.7
# 39      COL    5.7
# 40      LTU    6.4
# 41      CRI    6.3

# %%
df = df.rename(columns={'Value': 'BLI'})

# %%
df
# Out:
#    LOCATION  BLI
# 0       AUS  7.1
# 1       AUT  7.2
# 2       BEL  6.8
# 3       CAN  7.0
# 4       CZE  6.9
# 5       DNK  7.5
# 6       FIN  7.9
# 7       FRA  6.7
# 8       DEU  7.3
# 9       GRC  5.8
# 10      HUN  6.0
# 11      ISL  7.6
# 12      IRL  7.0
# 13      ITA  6.5
# 14      JPN  6.1
# 15      KOR  5.8
# 16      LUX  7.4
# 17      MEX  6.0
# 18      NLD  7.5
# 19      NZL  7.3
# 20      NOR  7.3
# 21      POL  6.1
# 22      PRT  5.8
# 23      SVK  6.5
# 24      ESP  6.5
# 25      SWE  7.3
# 26      CHE  7.5
# 27      TUR  4.9
# 28      GBR  6.8
# 29      USA  7.0
# 30      BRA  6.1
# 31      CHL  6.2
# 32      EST  6.5
# 33      ISR  7.2
# 34      LVA  6.2
# 35      RUS  5.5
# 36      SVN  6.5
# 37      ZAF  4.9
# 38     OECD  6.7
# 39      COL  5.7
# 40      LTU  6.4
# 41      CRI  6.3

# %%
df.to_csv('Filtered_BLI.csv', index=None)

# %%
GPD = pd.read_csv('Filtered_GPD.csv')
BLI = pd.read_csv('Filtered_BLI.csv')

# %%
GPD
# Out:
#    LOCATION           GPD
# 0       AUS  56000.130076
# 1       AUT  57235.673886
# 2       BEL  54652.164337
# 3       CAN  47226.357276
# 4       CZE  42817.867499
# ..      ...           ...
# 61      ALB  14033.967211
# 62      SRB  19547.725670
# 63      GEO  14731.202573
# 64      CMR   3861.209890
# 65      SEN   3513.149951
#
# [66 rows x 2 columns]

# %%
BLI
# Out:
#    LOCATION  BLI
# 0       AUS  7.1
# 1       AUT  7.2
# 2       BEL  6.8
# 3       CAN  7.0
# 4       CZE  6.9
# 5       DNK  7.5
# 6       FIN  7.9
# 7       FRA  6.7
# 8       DEU  7.3
# 9       GRC  5.8
# 10      HUN  6.0
# 11      ISL  7.6
# 12      IRL  7.0
# 13      ITA  6.5
# 14      JPN  6.1
# 15      KOR  5.8
# 16      LUX  7.4
# 17      MEX  6.0
# 18      NLD  7.5
# 19      NZL  7.3
# 20      NOR  7.3
# 21      POL  6.1
# 22      PRT  5.8
# 23      SVK  6.5
# 24      ESP  6.5
# 25      SWE  7.3
# 26      CHE  7.5
# 27      TUR  4.9
# 28      GBR  6.8
# 29      USA  7.0
# 30      BRA  6.1
# 31      CHL  6.2
# 32      EST  6.5
# 33      ISR  7.2
# 34      LVA  6.2
# 35      RUS  5.5
# 36      SVN  6.5
# 37      ZAF  4.9
# 38     OECD  6.7
# 39      COL  5.7
# 40      LTU  6.4
# 41      CRI  6.3

# %%
df = pd.merge(BLI, GPD, how='inner', on='LOCATION')

# %%
df
# Out:
#    LOCATION  BLI            GPD
# 0       AUS  7.1   56000.130076
# 1       AUT  7.2   57235.673886
# 2       BEL  6.8   54652.164337
# 3       CAN  7.0   47226.357276
# 4       CZE  6.9   42817.867499
# 5       DNK  7.5   60768.060489
# 6       FIN  7.9   52294.342491
# 7       FRA  6.7   47982.359606
# 8       DEU  7.3   56454.181109
# 9       GRC  5.8   28349.491127
# 10      HUN  6.0   34169.922355
# 11      ISL  7.6   54330.385248
# 12      IRL  7.0   94646.640757
# 13      ITA  6.5   43150.115981
# 14      JPN  6.1   41867.153393
# 15      KOR  5.8   44694.939796
# 16      LUX  7.4  119407.898814
# 17      MEX  6.0   18978.937139
# 18      NLD  7.5   59821.266235
# 19      NZL  7.3   45457.178769
# 20      NOR  7.3   65135.920669
# 21      POL  6.1   34896.822600
# 22      PRT  5.8   34955.611560
# 23      SVK  6.5   32912.709886
# 24      ESP  6.5   38030.728528
# 25      SWE  7.3   56140.551353
# 26      CHE  7.5   71010.450577
# 27      TUR  4.9   27973.899303
# ...

# %%
df.to_csv('Data_for_training.csv')
